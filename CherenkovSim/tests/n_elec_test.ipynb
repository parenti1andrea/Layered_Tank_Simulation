# %%
import sys
import os

# Add the parent directory of "tests" to sys.path
sys.path.append(os.path.abspath("/Users/workspace/Software/Layered_Tank_Simulation/CherenkovSim/"))

# %%
from cherenkov_sim.particle import Particle
from cherenkov_sim.electron import Electron
from cherenkov_sim.material import Material
from cherenkov_sim.tracker import ParticleTracker
from cherenkov_sim.constants import ALPHA, R_TANK, H_TANK

import numpy as np
from astropy import units as u
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
ice = Material(
    name = 'Ice',
    Z_A = 0.55509 * u.mol / u.g,
    rho = 0.9180 * u.g / u.cm**3,
    I = 79.7 * u.eV, 
    n = 1.309,
    X0 = 39.31 * u.cm, 
    delta_file = '/Users/workspace/Software/PHYS-F-420/lesson2/delta_elec.txt'
)

water = Material(
    name = 'water',
    Z_A = 0.55509 * u.mol / u.g,
    rho = 1 * u.g / u.cm**3,
    I = 79.7 * u.eV,
    n = 1.333,
    X0 = 36.08 * u.cm, 
    delta_file = '/Users/workspace/Software/PHYS-F-420/lesson2/delta_elec.txt'
)

# %%
# Define primary energy 
e = 100 * u.MeV

# %%
# Extract starting position randomly from a circle corresponding to the top of the tank
N_event = 1000 # Choose number of particles 

# Gen. surface radius 
R_gen = 180 * u.cm 
 
def rnd_tank_start(R_gen, N_event): 
    r = R_gen * np.sqrt(np.random.uniform(0,1,size=N_event))
    alpha = np.random.uniform(0,2*np.pi, size=N_event) 
    z_value = 140 
    x0 = r * np.cos(alpha)   
    y0 = r * np.sin(alpha)  
    z0 = np.full(N_event,z_value) * u.cm
    return x0, y0, z0   


def rnd_direction(N_event):
    phi = np.random.uniform(0,2*np.pi, size=N_event)

    theta_0 = 0 * u.deg 
    theta_1 = 30 * u.deg 
    cos_theta_squared = np.random.uniform(np.cos(theta_1.to(u.rad))**2,np.cos(theta_0.to(u.rad))**2, size=N_event)
    cos_theta = np.sqrt(cos_theta_squared)
    theta = np.arccos(cos_theta) 
    return theta * u.rad, phi * u.rad

# %%
# Track muons inside the tank, considering energy loss and Cherenkov produciton 

muon_theta, muon_phi = rnd_direction(N_event)
x0,y0,z0 = rnd_tank_start(R_gen, N_event)  

initial_position = np.array([x0[0].value,y0[0].value,z0[0].value]) * u.cm
theta = muon_theta[0]

# %%
# Create list to store photon position 

all_photons = []
all_photons_z = []
all_photons_r = []

# %%
for i_evt in range(0, N_event):

    print('Simulating muon track #',i_evt)
    initial_position = np.array([x0[i_evt].value,y0[i_evt].value,z0[i_evt].value]) * u.cm

    # Define particle 
    elec = Electron(energy = e)
    elec.load_delta_parameter(ice)

    # Create the Tracker
    tracker = ParticleTracker(elec, ice, step_size= - 1.0 * u.cm,
                      position=initial_position, 
                      zenith=muon_theta[i_evt], 
                      azimuth=muon_phi[i_evt])
    
    tracker.propagate(lambda1 = 300 * u.nm, lambda2 = 600 * u.nm)

    all_photons.extend(tracker.cherenkov_photons)
    all_photons_z.extend(tracker.cherenkov_photons_z)
    all_photons_r.extend(tracker.cherenkov_photons_r)
# Out:
# Simulating muon track # 0
# Starting particle tracking at position [ 66.1271905  111.43365649 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track #
140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 205
# Starting particle tracking at position [  44.29177798 -102.42282553  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 206
# Starting particle tracking at position [ 98.26503651  25.19007238 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 207
# Starting particle tracking at position [-34.54241496 122.90660512 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 208
# Starting particle tracking at position [140.86613111 -69.85422161 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 209
# Starting particle tracking at position [ 14.87607227 128.41318331 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 210
# Starting particle tracking at position [-101.7316054   -79.44936168  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 211
# Starting particle tracking at position [-87.87521453 -70.46547352 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 212
# Starting particle tracking at position [  28.8244063  -153.60873597  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 213
# Starting particle tracking at position [-131.61156398   49.31962978  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 214
# Starting particle tracking at position [-106.19300733   70.94596073  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 215
# Starting particle tracking at position [-57.93396933  45.00823516 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 216
# Starting particle tracking at position [ 72.74245227 128.53316892 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 217
# Starting particle tracking at position [-117.56050442  106.02655618  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 218
# Starting particle tracking at position [ 49.63465776 -85.93733939 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 219
# Starting particle tracking at position [  6.2358294  -52.61706457 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 220
# Starting particle tracking at position [  5.57181863  17.03066081 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 221
# Starting particle tracking at position [   6.35406573 -107.1199047   140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 222
# Starting particle tracking at position [ 115.69186555 -110.73073427  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 223
# Starting particle tracking at position [ -7.20069566 163.91771884 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 224
# Starting particle tracking at position [-115.45618644  -27.05696514  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 225
# Starting particle tracking at position [112.10537057 121.67193554 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 226
# Starting particle tracking at position [  4.30931703  95.37689531 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 227
# Starting particle tracking at position [-130.09033859  -93.23751364  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 228
# Starting particle tracking at position [ 35.79953693  34.05694161 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 229
# Starting particle tracking at position [ 100.63813947 -110.12019319  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 230
# Starting particle tracking at position [ -39.30017889 -139.90895026  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 231
# Starting particle tracking at position [ 50.59911876 -94.69191085 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 232
# Starting particle tracking at position [-40.84915726 -20.50472953 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 233
# Starting particle tracking at position [ -51.94559196 -103.05219534  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 234
# Starting particle tracking at position [148.11816617  46.49657812 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 235
# Starting particle tracking at position [  43.90707229 -127.78972459  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 236
# Starting particle tracking at position [-122.83095954  -76.42522506  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 237
# Starting particle tracking at position [   8.06924581 -176.83160347  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 238
# Starting particle tracking at position [-159.40839006  -54.29621975  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 239
# Starting particle tracking at position [-102.19150417  -32.7023136   140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 240
# Starting particle tracking at position [ 77.07762291 104.80190367 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 241
# Starting particle tracking at position [ -42.140423   -127.10350681  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 242
# Starting particle tracking at position [ 123.8847854  -127.38397099  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 243
# Starting particle tracking at position [ 68.78426812  37.09549554 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 244
# Starting particle tracking at position [ -38.99783231 -116.62920827  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 245
# Starting particle tracking at position [-62.70652042 -12.53551887 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 246
# Starting particle tracking at position [-19.67503345 154.13185068 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 247
# Starting particle tracking at position [  5.30117856  96.27528511 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 248
# Starting particle tracking at position [ 53.74759116  46.58653607 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 249
# Starting particle tracking at position [170.75973941  -7.52069967 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 250
# Starting particle tracking at position [-61.43287069  98.59830538 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 251
# Starting particle tracking at position [ 38.85002091 160.90591789 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 252
# Starting particle tracking at position [-115.89695744   15.4657993   140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 253
# Starting particle tracking at position [171.69122363  41.13381312 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 254
# Starting particle tracking at position [ 79.54150342 -40.17138262 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 255
# Starting particle tracking at position [-74.38746599  -6.94545465 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 256
# Starting particle tracking at position [-97.75204818  79.24171222 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 257
# Starting particle tracking at position [-108.92173833   95.20702839  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 258
# Starting particle tracking at position [145.98563231 -60.97323684 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 259
# Starting particle tracking at position [ -75.53050053 -160.09937463  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 260
# Starting particle tracking at position [152.38738115  13.8091876  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 261
# Starting particle tracking at position [-70.92036135  83.59839798 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 262
# Starting particle tracking at position [-90.81888519 -47.11242627 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 263
# Starting particle tracking at position [ -5.69894069 160.40148099 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 264
# Starting particle tracking at position [ 24.2528267    6.18724642 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 265
# Starting particle tracking at position [158.9079369   -1.79944097 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 266
# Starting particle tracking at position [-90.06455702  57.486136   140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 267
# Starting particle tracking at position [ -63.73720362 -134.19308078  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 268
# Starting particle tracking at position [-112.41352118   21.08067665  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 269
# Starting particle tracking at position [ 18.71332226 -26.11050289 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 270
# Starting particle tracking at position [106.70529484  67.21643297 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 271
# Starting particle tracking at position [ 57.60294284 -54.08518072 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 272
# Starting particle tracking at position [ 63.33083369 -66.05908352 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 273
# Starting particle tracking at position [  25.20585939 -122.22146988  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 274
# Starting particle tracking at position [-37.35933007 123.00055659 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 275
# Starting particle tracking at position [-97.61110778 124.50157811 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 276
# Starting particle tracking at position [ 123.48599488 -112.90993994  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 277
# Starting particle tracking at position [-169.20559153  -42.88843173  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 278
# Starting particle tracking at position [140.34595669  17.23996317 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 279
# Starting particle tracking at position [ 89.53372396 133.39255589 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 280
# Starting particle tracking at position [  9.9805308   56.90226276 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 281
# Starting particle tracking at position [ 59.76056379  -7.75511418 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 282
# Starting particle tracking at position [ 93.49205773  15.1795672  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# ...
# Simulating muon track # 906
# Starting particle tracking at position [-20.51299632  77.4022672  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 907
# Starting particle tracking at position [-102.13184563    3.37312239  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 908
# Starting particle tracking at position [155.38075317  45.48317044 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 909
# Starting particle tracking at position [-25.8182006  -14.70916252 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 910
# Starting particle tracking at position [-157.80147355   18.24186868  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 911
# Starting particle tracking at position [ -32.32432956 -112.41139631  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 912
# Starting particle tracking at position [ 12.8645458  -59.24462761 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 913
# Starting particle tracking at position [-38.006596   171.36942983 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 914
# Starting particle tracking at position [-149.13671558  -37.76825823  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 915
# Starting particle tracking at position [ 25.81800153  30.26247249 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 916
# Starting particle tracking at position [122.51937098 -18.93577633 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 917
# Starting particle tracking at position [117.72261251 111.05854908 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 918
# Starting particle tracking at position [-123.71197111   65.70583165  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 919
# Starting particle tracking at position [  0.74848194 -96.22224447 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 920
# Starting particle tracking at position [ 40.99790883  99.11869906 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 921
# Starting particle tracking at position [ 32.68331959 160.11552446 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 922
# Starting particle tracking at position [-19.29458742  32.24909986 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 923
# Starting particle tracking at position [-135.93974391   59.83188118  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 924
# Starting particle tracking at position [ -11.75809791 -144.58945274  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 925
# Starting particle tracking at position [-50.98063768 121.09407966 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 926
# Starting particle tracking at position [-121.99148265   32.79940496  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 927
# Starting particle tracking at position [-30.37225225 144.78120095 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 928
# Starting particle tracking at position [-47.61198555   8.18121269 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 929
# Starting particle tracking at position [-102.26549333   37.80906314  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 930
# Starting particle tracking at position [ 37.50376666   3.98344998 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 931
# Starting particle tracking at position [ 91.12698494  24.99119262 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 932
# Starting particle tracking at position [ 53.50445516 168.120275   140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 933
# Starting particle tracking at position [103.3515077  19.4313556 140.       ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 934
# Starting particle tracking at position [151.37330896  29.8653135  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 935
# Starting particle tracking at position [ 13.76472215  32.1431202  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 936
# Starting particle tracking at position [-122.88927656  -99.73991571  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 937
# Starting particle tracking at position [-42.43512636 161.04608781 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 938
# Starting particle tracking at position [-151.93205953   35.50427302  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 939
# Starting particle tracking at position [ 80.80991135  65.8845559  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 940
# Starting particle tracking at position [-113.17601557   20.21665645  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 941
# Starting particle tracking at position [139.33180345  72.64240678 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 942
# Starting particle tracking at position [-136.15206185   17.18369621  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 943
# Starting particle tracking at position [ -70.8069729  -142.67580459  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 944
# Starting particle tracking at position [-153.31738515  -20.07073779  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 945
# Starting particle tracking at position [ 38.37389248 -85.63685156 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 946
# Starting particle tracking at position [-161.24097028   -7.4306364   140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 947
# Starting particle tracking at position [115.41361076  25.98346956 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 948
# Starting particle tracking at position [ 65.2714605   29.70168204 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 949
# Starting particle tracking at position [  69.58556107 -109.21782138  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 950
# Starting particle tracking at position [-37.63109938  72.06227249 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 951
# Starting particle tracking at position [  99.80074218 -127.67959074  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 952
# Starting particle tracking at position [134.28154948  -8.34928638 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 953
# Starting particle tracking at position [  64.30256478 -151.4252359   140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 954
# Starting particle tracking at position [168.26505074 -56.27505631 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 955
# Starting particle tracking at position [113.13729089  96.39486891 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 956
# Starting particle tracking at position [-43.0347129 -59.1713893 140.       ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 957
# Starting particle tracking at position [-58.84544527 -97.42705212 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 958
# Starting particle tracking at position [-68.73591665 120.88522525 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 959
# Starting particle tracking at position [ 45.51086818  53.90540399 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 960
# Starting particle tracking at position [  58.9319009  -108.69073139  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 961
# Starting particle tracking at position [-55.94487426 122.13139142 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 962
# Starting particle tracking at position [132.78760386 -45.35973462 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 963
# Starting particle tracking at position [-49.70109186 -70.76607396 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 964
# Starting particle tracking at position [-122.13851158   23.44259758  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 965
# Starting particle tracking at position [-88.28935694  84.14068054 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 966
# Starting particle tracking at position [ -15.46421974 -120.47248076  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 967
# Starting particle tracking at position [178.83139655 -13.43305069 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 968
# Starting particle tracking at position [ 54.09770485 -63.28674954 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 969
# Starting particle tracking at position [  91.95672292 -150.97004386  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 970
# Starting particle tracking at position [-17.54800259 -97.24368707 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 971
# Starting particle tracking at position [140.34038259  22.20370836 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 972
# Starting particle tracking at position [-157.57748677   64.25683969  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 973
# Starting particle tracking at position [  3.81000765  93.92654114 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 974
# Starting particle tracking at position [ 52.12565849  53.11652495 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 975
# Starting particle tracking at position [ -75.13790824 -136.88376299  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 976
# Starting particle tracking at position [ -82.31473683 -123.970821    140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 977
# Starting particle tracking at position [ -3.6515676   80.33290137 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 978
# Starting particle tracking at position [ 21.00595262   4.39733974 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 979
# Starting particle tracking at position [ 30.77835561  27.96801835 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 980
# Starting particle tracking at position [-102.12224407  -50.15321376  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 981
# Starting particle tracking at position [ 100.88766635 -108.54618905  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 982
# Starting particle tracking at position [ 73.81124384  96.81390529 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 983
# Starting particle tracking at position [ -1.67702617 172.120497   140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 984
# Starting particle tracking at position [  51.30425721 -161.73523054  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 985
# Starting particle tracking at position [-122.06451309   72.2949807   140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 986
# Starting particle tracking at position [ -0.45284516 -80.60086549 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 987
# Starting particle tracking at position [-29.70409952  89.0254793  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 988
# Starting particle tracking at position [ 59.3475352   2.2815921 140.       ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 989
# Starting particle tracking at position [ 75.20800019 132.62751094 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 990
# Starting particle tracking at position [-94.31045935 145.10593958 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 991
# Starting particle tracking at position [-69.30998345 131.03400249 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 992
# Starting particle tracking at position [ 56.84133907  48.8974457  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 993
# Starting particle tracking at position [ 25.92367221   1.43965616 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 994
# Starting particle tracking at position [-32.68604207 -42.8080865  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 995
# Starting particle tracking at position [  78.31056641 -121.37315568  140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 996
# Starting particle tracking at position [ 67.21734895 132.16783001 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 997
# Starting particle tracking at position [ 85.33644417  -7.67412765 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 998
# Starting particle tracking at position [-93.16881802 148.06622082 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 999
# Starting particle tracking at position [ 96.53388766 127.85215839 140.        ] cm with energy 0.10 GeV
# Tracking complete. Particle stopped.

# %%
len(tracker.cherenkov_photons_z)
len(all_photons_z)
# Out:
# 7219638

# %%
# Define range and bins of photon density histogram 

bin_width = 10
r_bins = np.arange(0,R_TANK.value+bin_width,bin_width)
z_bins = np.arange(0,H_TANK.value+bin_width,bin_width)

# Compute volume corresponding to each bin 
r_min, r_max = r_bins[:-1], r_bins[1:]
z_min, z_max = z_bins[:-1], z_bins[1:]

vol = np.zeros((len(r_min),len(z_min))) 
r_centers = (r_min+r_max) / 2.
z_centers = (z_min + z_max) / 2.

for i in range(len(r_min)): 
    for j in range(len(z_min)): 
        vol[i][j] = np.pi * (r_max[i]**2-r_min[i]**2)*(z_max[j]-z_min[j])
        
r_centers, z_centers = np.meshgrid(r_centers,z_centers)

# %%
hist2d = plt.hist2d(all_photons_r, all_photons_z, bins=[r_bins,z_bins], norm=mpl.colors.LogNorm(), cmap = plt.cm.coolwarm )
#hist2d = plt.hist2d(r_photon, z_photon, bins=[r_bins,z_bins], norm=mpl.colors.LogNorm(vmin=np.min(hist2d[0])), cmap = plt.cm.coolwarm)
#hist2d = plt.hist2d(r_photon, z_photon, bins=[r_bins,z_bins], cmap = plt.cm.coolwarm)

plt.xlabel('R tank / m',size=12)
plt.ylabel('H tank / m',size=12)
cbar = plt.colorbar()
cbar.set_label('# Cherenkov photons', rotation=270, labelpad=10)

# %%
plt.figure(dpi=100)
bin_count = hist2d[0]
ph_density = bin_count / vol 

print(r_centers.shape)
print(z_centers.shape)

#plt.scatter(r_centers, z_centers, c = ph_density.T, marker='s')
#plt.colorbar()

plt.scatter(r_centers, z_centers, s=ph_density.T*7, marker='s', c='red')
plt.xlabel('R tank / m',size=12)
plt.ylabel('H tank / m',size=12)
# Out:
# (12, 15)
# (12, 15)
# Text(0, 0.5, 'H tank / m')
