# %%
import sys
import os

# Add the parent directory of "tests" to sys.path
sys.path.append(os.path.abspath("/Users/workspace/Software/Layered_Tank_Simulation/CherenkovSim/"))

# %%
from cherenkov_sim.particle import Particle
from cherenkov_sim.muon import Muon
from cherenkov_sim.material import Material
from cherenkov_sim.tracker import ParticleTracker
from cherenkov_sim.constants import ALPHA, R_TANK, H_TANK

import numpy as np
from astropy import units as u
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
ice = Material(
    name = 'Ice',
    Z_A = 0.55509 * u.mol / u.g,
    rho = 0.9180 * u.g / u.cm**3,
    I = 79.7 * u.eV, 
    n = 1.309,
    X0 = 39.31 * u.cm, 
    delta_file = '/Users/workspace/Software/PHYS-F-420/lesson2/delta_elec.txt'
)

water = Material(
    name = 'water',
    Z_A = 0.55509 * u.mol / u.g,
    rho = 1 * u.g / u.cm**3,
    I = 79.7 * u.eV,
    n = 1.333,
    X0 = 36.08 * u.cm, 
    delta_file = '/Users/workspace/Software/PHYS-F-420/lesson2/delta_elec.txt'
)

# %%
# Define primary energy 
e = 1 * u.GeV

# %%
# Extract starting position randomly from a circle corresponding to the top of the tank
N_event = 1000 # Choose number of particles 

# Gen. surface radius 
R_gen = 180 * u.cm 
 
def rnd_tank_start(R_gen, N_event): 
    r = R_gen * np.sqrt(np.random.uniform(0,1,size=N_event))
    alpha = np.random.uniform(0,2*np.pi, size=N_event) 
    z_value = 140 
    x0 = r * np.cos(alpha)   
    y0 = r * np.sin(alpha)  
    z0 = np.full(N_event,z_value) * u.cm
    return x0, y0, z0   


def rnd_direction(N_event):
    phi = np.random.uniform(0,2*np.pi, size=N_event)

    theta_0 = 0 * u.deg 
    theta_1 = 30 * u.deg 
    cos_theta_squared = np.random.uniform(np.cos(theta_1.to(u.rad))**2,np.cos(theta_0.to(u.rad))**2, size=N_event)
    cos_theta = np.sqrt(cos_theta_squared)
    theta = np.arccos(cos_theta) 
    return theta * u.rad, phi * u.rad

# %%
# Track muons inside the tank, considering energy loss and Cherenkov produciton 

muon_theta, muon_phi = rnd_direction(N_event)
x0,y0,z0 = rnd_tank_start(R_gen, N_event)  

initial_position = np.array([x0[0].value,y0[0].value,z0[0].value]) * u.cm
theta = muon_theta[0]

# %%
# Create list to store photon position 

all_photons = []
all_photons_z = []
all_photons_r = []

# %%
for i_evt in range(0, N_event):

    print('Simulating muon track #',i_evt)
    initial_position = np.array([x0[i_evt].value,y0[i_evt].value,z0[i_evt].value]) * u.cm

    # Define particle 
    muon = Muon(energy = e)

    # Create the Tracker
    tracker = ParticleTracker(muon, ice, step_size= - 1.0 * u.cm,
                      position=initial_position, 
                      zenith=muon_theta[i_evt], 
                      azimuth=muon_phi[i_evt])
    
    tracker.propagate(lambda1 = 300 * u.nm, lambda2 = 600 * u.nm)

    all_photons.extend(tracker.cherenkov_photons)
    all_photons_z.extend(tracker.cherenkov_photons_z)
    all_photons_r.extend(tracker.cherenkov_photons_r)
# Out:
# Simulating muon track # 0
# Starting muon tracking at position [ 69.84953948  10.9185728  140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 1
# Starting muon tracking at position [-121.00194867    3.50421583  140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 2
# Starting muon tracking at position [ -84.49778688 -127.16855883  140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track #
140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 979
# Starting muon tracking at position [160.99435908 -30.92396412 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 980
# Starting muon tracking at position [  4.82778386 168.75502709 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 981
# Starting muon tracking at position [138.18812134  20.37803395 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 982
# Starting muon tracking at position [ 95.4111811   78.59473772 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 983
# Starting muon tracking at position [-13.8817219  161.25852426 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 984
# Starting muon tracking at position [ -6.3361318  -13.25229567 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 985
# Starting muon tracking at position [ -27.99323934 -107.26146384  140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 986
# Starting muon tracking at position [  88.32468982 -130.47502204  140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 987
# Starting muon tracking at position [-63.51241611 -56.79458454 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 988
# Starting muon tracking at position [-122.66073098  -67.27436871  140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 989
# Starting muon tracking at position [-55.4207781  125.11731635 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 990
# Starting muon tracking at position [ 102.1404462  -124.92349648  140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 991
# Starting muon tracking at position [  0.30929134 119.34959936 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 992
# Starting muon tracking at position [-129.3697786    32.52398766  140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 993
# Starting muon tracking at position [  4.65679739  82.92825911 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 994
# Starting muon tracking at position [ 41.90630867  -5.48017078 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 995
# Starting muon tracking at position [-60.8168205  101.80156433 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 996
# Starting muon tracking at position [-86.6133384   87.16530589 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 997
# Starting muon tracking at position [-165.35396216   22.95404852  140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 998
# Starting muon tracking at position [ -10.03181769 -119.86355336  140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.
# Simulating muon track # 999
# Starting muon tracking at position [143.94160013 -40.62188354 140.        ] cm with energy 1.00 GeV
# Tracking complete. Particle stopped.

# %%
len(tracker.cherenkov_photons_z)
len(all_photons_z)
# Out:
# 26054483

# %%
# Define range and bins of photon density histogram 

bin_width = 10
r_bins = np.arange(0,R_TANK.value+bin_width,bin_width)
z_bins = np.arange(0,H_TANK.value+bin_width,bin_width)

# Compute volume corresponding to each bin 
r_min, r_max = r_bins[:-1], r_bins[1:]
z_min, z_max = z_bins[:-1], z_bins[1:]

vol = np.zeros((len(r_min),len(z_min))) 
r_centers = (r_min+r_max) / 2.
z_centers = (z_min + z_max) / 2.

for i in range(len(r_min)): 
    for j in range(len(z_min)): 
        vol[i][j] = np.pi * (r_max[i]**2-r_min[i]**2)*(z_max[j]-z_min[j])
        
r_centers, z_centers = np.meshgrid(r_centers,z_centers)

# %%
hist2d = plt.hist2d(all_photons_r, all_photons_z, bins=[r_bins,z_bins], norm=mpl.colors.LogNorm(), cmap = plt.cm.coolwarm )
#hist2d = plt.hist2d(r_photon, z_photon, bins=[r_bins,z_bins], norm=mpl.colors.LogNorm(vmin=np.min(hist2d[0])), cmap = plt.cm.coolwarm)
#hist2d = plt.hist2d(r_photon, z_photon, bins=[r_bins,z_bins], cmap = plt.cm.coolwarm)

plt.xlabel('R tank / m',size=12)
plt.ylabel('H tank / m',size=12)
cbar = plt.colorbar()
cbar.set_label('# Cherenkov photons', rotation=270, labelpad=10)

# %%
plt.figure(dpi=100)
bin_count = hist2d[0]
ph_density = bin_count / vol 

print(r_centers.shape)
print(z_centers.shape)

#plt.scatter(r_centers, z_centers, c = ph_density.T, marker='s')
#plt.colorbar()

plt.scatter(r_centers, z_centers, s=ph_density.T*7, marker='s', c='red')
plt.xlabel('R tank / m',size=12)
plt.ylabel('H tank / m',size=12)
# Out:
# (12, 15)
# (12, 15)
# Text(0, 0.5, 'H tank / m')
